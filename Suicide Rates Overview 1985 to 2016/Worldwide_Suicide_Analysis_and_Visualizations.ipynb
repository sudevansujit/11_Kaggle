# %% [markdown]
# # Worldwide_Suicide_Analysis_and_Visualizations

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
suicide = pd.read_csv('master.csv', usecols = [0,1,2,3,4,5,11], index_col=['country', 'year']).sort_index()
suicide.head(20)
# Out:
#                  sex          age  suicides_no  population       generation
# country year
# Albania 1987    male  15-24 years           21      312900     Generation X
#         1987    male  35-54 years           16      308000           Silent
#         1987  female  15-24 years           14      289700     Generation X
#         1987    male    75+ years            1       21800  G.I. Generation
#         1987    male  25-34 years            9      274300          Boomers
#         1987  female    75+ years            1       35600  G.I. Generation
#         1987  female  35-54 years            6      278800           Silent
#         1987  female  25-34 years            4      257200          Boomers
#         1987    male  55-74 years            1      137500  G.I. Generation
#         1987  female   5-14 years            0      311000     Generation X
#         1987  female  55-74 years            0      144600  G.I. Generation
#         1987    male   5-14 years            0      338200     Generation X
#         1988  female    75+ years            2       36400  G.I. Generation
#         1988    male  15-24 years           17      319200     Generation X
#         1988    male    75+ years            1       22300  G.I. Generation
#         1988    male  35-54 years           14      314100           Silent
#         1988    male  55-74 years            4      140200  G.I. Generation
#         1988  female  15-24 years            8      295600     Generation X
#         1988  female  55-74 years            3      147500  G.I. Generation
#         1988  female  25-34 years            5      262400          Boomers

# %% [markdown]
# ## Total Suicides Every Year all over the world

# %%
suicide.groupby('year').suicides_no.sum()
# Out:
# year
# 1985    116063
# 1986    120670
# 1987    126842
# 1988    121026
# 1989    160244
# 1990    193361
# 1991    198020
# 1992    211473
# 1993    221565
# 1994    232063
# 1995    243544
# 1996    246725
# 1997    240745
# 1998    249591
# 1999    256119
# 2000    255832
# 2001    250652
# 2002    256095
# 2003    256079
# 2004    240861
# 2005    234375
# 2006    233361
# 2007    233408
# 2008    235447
# 2009    243487
# 2010    238702
# 2011    236484
# 2012    230160
# 2013    223199
# 2014    222984
# 2015    203640
# 2016     15603
# Name: suicides_no, dtype: int64

# %%
# Year wise Plot
plt.figure(figsize=(15,10))
suicide.groupby('year').suicides_no.sum().plot(kind = 'bar')
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15, rotation=0)
plt.show()

# %% [markdown]
# ### Total Suicide from 1985 - 2016

# %%
suicide.suicides_no.sum()
# Out:
# 6748420

# %% [markdown]
# ### Male and Female suicides sum

# %%
suicide.groupby('sex').suicides_no.sum()
# Out:
# sex
# female    1559510
# male      5188910
# Name: suicides_no, dtype: int64

# %% [markdown]
# ### Yearly comparison of male and male suicides all over the world

# %%
suicide.groupby(['year','sex']).suicides_no.sum().head(10)
# Out:
# year  sex
# 1985  female     32479
#       male       83584
# 1986  female     33852
#       male       86818
# 1987  female     35006
#       male       91836
# 1988  female     33015
#       male       88011
# 1989  female     41361
#       male      118883
# Name: suicides_no, dtype: int64

# %%
# Yearly plot of Male and Female Suicides
plt.figure(figsize=(15,10))
suicide.groupby(['year','sex']).suicides_no.sum().plot(kind = 'bar')

plt.show()

# %% [markdown]
# ### Country wise suicides from 1985 - 2016

# %%
suicide.groupby(['country']).suicides_no.sum().head(10)
# Out:
# country
# Albania                 1970
# Antigua and Barbuda       11
# Argentina              82219
# Armenia                 1905
# Aruba                    101
# Australia              70111
# Austria                50073
# Azerbaijan              1656
# Bahamas                   93
# Bahrain                  463
# Name: suicides_no, dtype: int64

# %%
suicide.groupby(['country']).suicides_no.sum().tail(10)
# Out:
# country
# Thailand                 110643
# Trinidad and Tobago        4039
# Turkey                    10131
# Turkmenistan               8624
# Ukraine                  319950
# United Arab Emirates        622
# United Kingdom           136805
# United States           1034013
# Uruguay                   13138
# Uzbekistan                34803
# Name: suicides_no, dtype: int64

# %% [markdown]
# ### Total Suicides in United States

# %%
suicide.groupby(['country']).suicides_no.sum().loc['United States']
# Out:
# 1034013

# %%
suicide.groupby(['country']).suicides_no.sum().loc['Russian Federation']
# Out:
# 1209742

# %%
# Sorted country wise suicide Plot
plt.figure(figsize=(15,10))
suicide.groupby(['country']).suicides_no.sum().sort_values().plot(kind = 'bar')

# %% [markdown]
# ### Age wise sum of suicides in all Countries from 1985 - 2016

# %%
suicide.groupby(['country','age']).suicides_no.sum().head(10)
# Out:
# country              age
# Albania              15-24 years    546
#                      25-34 years    427
#                      35-54 years    591
#                      5-14 years      61
#                      55-74 years    264
#                      75+ years       81
# Antigua and Barbuda  15-24 years      0
#                      25-34 years      1
#                      35-54 years      6
#                      5-14 years       0
# Name: suicides_no, dtype: int64

# %%
suicide.groupby(['country','age']).sum().head(12)
# Out:
#                                  suicides_no  population
# country             age
# Albania             15-24 years          546    12204973
#                     25-34 years          427    10018581
#                     35-54 years          591    15971048
#                     5-14 years            61    14081268
#                     55-74 years          264     8343071
#                     75+ years             81     1706526
# Antigua and Barbuda 15-24 years            0      385458
#                     25-34 years            1      370802
#                     35-54 years            6      537430
#                     5-14 years             0      421230
#                     55-74 years            4      212024
#                     75+ years              0       63284

# %% [markdown]
# ### Age wise suicides in United States

# %%
suicide.groupby(['country','age']).sum().loc['United States']
# Out:
#              suicides_no  population
# age
# 15-24 years       141679  1238381995
# 25-34 years       182047  1277625343
# 35-54 years       380917  2371577220
# 5-14 years          8923  1205493232
# 55-74 years       224770  1460664960
# 75+ years          95677   500284451

# %% [markdown]
# ### Age wise suicides of all Countries

# %%
suicide.groupby(['age']).sum().head(12)
# Out:
#              suicides_no   population
# age
# 15-24 years       808542   8642946896
# 25-34 years      1123912   8438103587
# 35-54 years      2452141  14375888123
# 5-14 years         52264   8398693237
# 55-74 years      1658443   8803245340
# 75+ years         653118   2663281253

# %%
# Worldwide suicides by age group
plt.figure(figsize=(10,8))
suicide.groupby(['age']).suicides_no.sum().sort_values().plot(kind = 'bar')
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=15, rotation=0)
plt.show()

# %%
# World wide male and female age group suicides 
plt.figure(figsize=(10,8))
suicide.groupby(['age', 'sex']).suicides_no.sum().sort_values().plot(kind = 'bar')

plt.show()

# %%
suicide.head()
# Out:
#                  sex          age  suicides_no  population       generation
# country year
# Albania 1987    male  15-24 years           21      312900     Generation X
#         1987    male  35-54 years           16      308000           Silent
#         1987  female  15-24 years           14      289700     Generation X
#         1987    male    75+ years            1       21800  G.I. Generation
#         1987    male  25-34 years            9      274300          Boomers

# %%
suicide.groupby(['country','sex']).suicides_no.sum().head(10)
# Out:
# country              sex
# Albania              female      693
#                      male       1277
# Antigua and Barbuda  female        1
#                      male         10
# Argentina            female    18326
#                      male      63893
# Armenia              female      495
#                      male       1410
# Aruba                female       17
#                      male         84
# Name: suicides_no, dtype: int64

# %% [markdown]
# ## Country wise male and female suicide Plot

# %%
plt.figure(figsize=(50,30))
suicide.groupby(['country', 'sex']).suicides_no.sum().plot(kind = 'bar')

# %% [markdown]
# ## Plotting only male or female suicides all over the world

# %%
suicide2 = pd.read_csv('master.csv')
suicide2.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
df = suicide2.pivot_table(values='suicides_no', index='country', columns='sex',aggfunc='sum')
df.head()
# Out:
# sex                  female   male
# country
# Albania                 693   1277
# Antigua and Barbuda       1     10
# Argentina             18326  63893
# Armenia                 495   1410
# Aruba                    17     84

# %%
df.tail()
# Out:
# sex                   female    male
# country
# United Arab Emirates      98     524
# United Kingdom         32687  104118
# United States         213797  820216
# Uruguay                 2820   10318
# Uzbekistan              9260   25543

# %%
df['Total_f_m'] = df['female'] + df['male']
df.head()
# Out:
# sex                  female   male  Total_f_m
# country
# Albania                 693   1277       1970
# Antigua and Barbuda       1     10         11
# Argentina             18326  63893      82219
# Armenia                 495   1410       1905
# Aruba                    17     84        101

# %% [markdown]
# ### Total suicides country wise

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(50,30))
df.groupby(['country']).Total_f_m.sum().plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## Selecting Individual Country and Sex

# %%
df.loc['United States','female']
# Out:
# 213797

# %% [markdown]
# ## Top 20 countries with high Female suicides

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(50,30))
df.groupby(['country']).female.sum().sort_values().tail(20).plot(kind = 'bar')
plt.xticks(fontsize=25, rotation=0)
plt.yticks(fontsize=15, rotation=0)
plt.show()

# %% [markdown]
# ## Top 20 countries with high Male suicides

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(50,30))
df.groupby(['country']).male.sum().sort_values().tail(20).plot(kind = 'bar')
plt.xticks(fontsize=25, rotation=45)
plt.yticks(fontsize=25, rotation=0)
plt.show()

# %%
suicide.groupby(['sex','country']).suicides_no.sum()
# Out:
# sex     country
# female  Albania                            693
#         Antigua and Barbuda                  1
#         Argentina                        18326
#         Armenia                            495
#         Aruba                               17
#         Australia                        15326
#         Austria                          13195
#         Azerbaijan                         412
#         Bahamas                             14
#         Bahrain                             80
#         Barbados                            33
#         Belarus                          10002
#         Belgium                          18012
#         Belize                              51
#         Bosnia and Herzegovina              70
#         Brazil                           49015
#         Bulgaria                          9968
#         Cabo Verde                           5
#         Canada                           24184
#         Chile                             6834
#         Colombia                         11343
#         Costa Rica                         979
#         Croatia                           4675
#         Cuba                             11675
#         Cyprus                              82
#         Czech Republic                    9247
#         Denmark                           4329
#         Dominica                             0
#         Ecuador                           6238
#         El Salvador                       3345
#                                          ...
# male    Puerto Rico                       7989
#         Qatar                              524
#         Republic of Korea               179115
#         Romania                          59595
#         Russian Federation              995412
#         Saint Kitts and Nevis                0
#         Saint Lucia                        196
#         Saint Vincent and Grenadines       113
#         San Marino                           4
#         Serbia                           17416
#         Seychelles                          89
#         Singapore                         6296
#         Slovakia                         11413
#         Slovenia                          8313
#         South Africa                      5719
#         Spain                            75533
#         Sri Lanka                        42043
#         Suriname                          1598
#         Sweden                           26612
#         Switzerland                      18478
#         Thailand                         82542
#         Trinidad and Tobago               3219
#         Turkey                            7562
#         Turkmenistan                      6528
#         Ukraine                         258573
#         United Arab Emirates               524
#         United Kingdom                  104118
#         United States                   820216
#         Uruguay                          10318
#         Uzbekistan                       25543
# Name: suicides_no, Length: 202, dtype: int64

# %%
suicide.groupby(['sex','country']).suicides_no.sum().loc[('female','United States')]
# Out:
# 213797

# %%
suicide.groupby(['sex','country']).suicides_no.sum().loc[('male','Japan')]
# Out:
# 555272

# %% [markdown]
# ### To be continued .........

# %% [raw]
# Thanks for reading and suggestions are welcome. I ll be improving this kernel using seaborn and will do some more data analysis using other columns.
